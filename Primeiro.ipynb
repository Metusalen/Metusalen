# %% [markdown]
# <a href="https://colab.research.google.com/github/Metusalen/Metusalen/blob/main/Primeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 49.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 31.8 MB/s eta 0:00:00
# ...

# %%
# Carregar bibliotecas
import numpy as np
import pandas as pd
from pycaret.regression import *
from sklearn.model_selection import train_test_split
import pycaret

# %%
import pandas as pd


try:
    df = pd.read_csv('/teste22.csv', delimiter=';')
except pd.errors.ParserError as e:
    print(f"Error reading CSV: {e}")

    with open('/teste22.csv', 'r') as f:
        for i, line in enumerate(f):
            print(f"Line {i+1}: {line}")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329883 entries, 0 to 329882
# Data columns (total 55 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            329883 non-null  int64
#  1   MESNASC       329883 non-null  int64
#  2   ANONASC       329882 non-null  float64
#  3   LOCNASC       329882 non-null  float64
#  4   CODMUNNASC    329882 non-null  float64
#  5   CODESTAB_DN   320823 non-null  float64
#  6   CEPNASC       300980 non-null  float64
#  7   CODMUNRES     329882 non-null  float64
#  8   IDADEMAE      329854 non-null  float64
#  9   ESTCIVMAE     326124 non-null  float64
#  10  ANONASCMAE    327153 non-null  float64
#  11  HORANASC      328421 non-null  float64
#  12  APGAR1        313014 non-null  float64
#  13  APGAR5        312684 non-null  float64
#  14  PESO          329252 non-null  float64
#  15  SEXO_DN       329882 non-null  object
#  16  IDANOMAL      323042 non-null  float64
# ...

# %%
train, validation = train_test_split(df, test_size=0.2,
                                     random_state=42)

# %%
train.dropna(subset=['APGAR1'], inplace=True)  # Remove linhas com valores nulos na coluna 'APGAR1'

from pycaret.regression import *
s = setup(data=train, target='APGAR1', session_id=123)
# Out:
# <style type="text/css">
# #T_fa3fb_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fa3fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa3fb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fa3fb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa3fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa3fb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fa3fb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fa3fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa3fb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fa3fb_row1_col1" class="data row1 col1" >APGAR1</td>
#     </tr>
#     <tr>
#       <th id="T_fa3fb_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_28ec3 th {
#   text-align: left;
# }
# ...
